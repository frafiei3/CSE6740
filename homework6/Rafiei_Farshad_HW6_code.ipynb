# %%
import pandas as pd
import numpy as np

# %%
col_names = ['word_freq_make',
'word_freq_address',
'word_freq_all',
'word_freq_3d',
'word_freq_our',
'word_freq_over',
'word_freq_remove',
'word_freq_internet',
'word_freq_order',
'word_freq_mail',
'word_freq_receive',
'word_freq_will',
'word_freq_people',
'word_freq_report',
'word_freq_addresses',
'word_freq_free',
'word_freq_business',
'word_freq_email',
'word_freq_you',
'word_freq_credit',
'word_freq_your',
'word_freq_font',
'word_freq_000',
'word_freq_money',
'word_freq_hp',
'word_freq_hpl',
'word_freq_george',
'word_freq_650',
'word_freq_lab',
'word_freq_labs',
'word_freq_telnet',
'word_freq_857',
'word_freq_data',
'word_freq_415',
'word_freq_85',
'word_freq_technology',
'word_freq_1999',
'word_freq_parts',
'word_freq_pm',
'word_freq_direct',
'word_freq_cs',
'word_freq_meeting',
'word_freq_original',
'word_freq_project',
'word_freq_re',
'word_freq_edu',
'word_freq_table',
'word_freq_conference',
'char_freq_;',
'char_freq_(',
'char_freq_[',
'char_freq_!',
'char_freq_$',
'char_freq_#',
'capital_run_length_average',
'capital_run_length_longest',
'capital_run_length_total',
'label']

# %%
data = pd.read_csv('spambase.data', header=None, names=col_names)

# %%
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %%
# There is no missing value in the data
data.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     4601.000000        4601.000000    4601.000000   4601.000000
# mean         0.104553           0.213015       0.280656      0.065425
# std          0.305358           1.290575       0.504143      1.395151
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.420000      0.000000
# max          4.540000          14.280000       5.100000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    4601.000000     4601.000000       4601.000000         4601.000000
# mean        0.312223        0.095901          0.114208            0.105295
# std         0.672513        0.273824          0.391441            0.401071
# ...

# %%
# Split the data into train and test data
from sklearn.model_selection import train_test_split
X = data[col_names[:-1]]
y = data['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2020)

# %% [markdown]
# ## CART

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
cart = DecisionTreeClassifier()
cart.fit(X_train, y_train)
y_pred = cart.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9218241042345277

# %%
print('Total misclassification rate for decision tree classifier: {}'.format(1-accuracy_score(y_test, y_pred)))
# Out:
# Total misclassification rate for decision tree classifier: 0.07817589576547235

# %%
from sklearn.tree import plot_tree, export_graphviz
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(25, 15))
plot_tree(cart, max_depth=3, fontsize=18, feature_names=data.columns, class_names=['non-spam', 'spam'])
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
error_forest = []
n_tree = []
error_tree = []
for num_tree in range(1,100,2):
    forest = RandomForestClassifier(n_estimators=num_tree)
    forest.fit(X_train, y_train)
    y_pred = forest.predict(X_test)
    n_tree.append(num_tree)
    error_forest.append(1 - accuracy_score(y_test, y_pred))
    error_tree.append(0.079261)
    

fig, ax = plt.subplots(figsize=(10, 10))
plt.plot(n_tree, error_forest, 'bo--', linewidth=2, markersize=12)
plt.plot(n_tree, error_tree, 'r', linewidth=2, markersize=12)
plt.ylabel('Total misclassification errror rate', fontsize=18)
plt.xlabel('# of trees', fontsize=18)
plt.legend(('Random Forest', 'Decision Tree'), loc='upper right', fontsize=24)

# %% [markdown]
# ## One class SVM

# %%
from sklearn.svm import OneClassSVM
nonSpam_X_train = X_train.loc[y_train==0]
y_pred = OneClassSVM(gamma=0.5).fit(nonSpam_X_train).predict(X_test)
y_pred[y_pred == -1] = 0
accuracy_score(y_test, 1-y_pred)
# Out:
# 0.4201954397394137
